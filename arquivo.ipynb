# %% [markdown]
# <a href="https://colab.research.google.com/github/Larissa-gif-has/analise-lunar/blob/analise-agencias/arquivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Larissa-gif-has/analise-lunar.git
# Out:
# Cloning into 'analise-lunar'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 10.21 KiB | 10.21 MiB/s, done.

# %%
# analisando o arquivo
import pandas as pd
df_lunar = pd.read_csv('/content/analise-lunar/Moonlanding.csv')

#atividade 1 - quantas missões cada agencia fez no total?
df_lunar["Operator"].value_counts()

#atividade 2- maior número de missões feitas por uma agencia
df_lunar["Operator"].value_counts().max()
# Out:
# 61
