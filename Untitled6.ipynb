# %% [markdown]
# <a href="https://colab.research.google.com/github/Larissa-gif-has/analise-lunar/blob/analise-resultados/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Importar dados do github

# %%
# !git clone https://github.com/Larissa-gif-has/analise-lunar.git
# Out:
# Cloning into 'analise-lunar'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 10.21 KiB | 10.21 MiB/s, done.

# %% [markdown]
# # Código

# %%
import pandas as pd

df_lua = pd.read_csv('/content/analise-lunar/Moonlanding.csv')

display(df_lua['Outcome'].count())
# Out:
# np.int64(166)

# %%
import pandas as pd

df_lua = pd.read_csv('/content/analise-lunar/Moonlanding.csv')

display(df_lua['Outcome'].value_counts())
# Out:
# Outcome
# Successful              78
# Launch failure          31
# Spacecraft failure      29
# Operational             14
# Partial failure          6
# Operational              3
# Precluded                2
# En route                 1
# Partial success          1
# Awaiting Deployment      1
# Name: count, dtype: int64
